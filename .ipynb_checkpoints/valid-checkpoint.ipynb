# %%
import numpy as np
import pandas as pd
from patsy import dmatrices, dmatrix
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
df_age = pd.read_csv('validation/id_age_val.csv')
df_vitals = pd.read_csv('validation/id_time_vitals_val.csv')
df_labs = pd.read_csv('validation/id_time_labs_val.csv')

# %%
df_age.describe()
# Out:
#                 ID          AGE
# count  1198.000000  1198.000000
# mean   4193.500000    61.171119
# std     345.977119    16.509128
# min    3595.000000    17.000000
# 25%    3894.250000    50.000000
# 50%    4193.500000    62.000000
# 75%    4492.750000    73.000000
# max    4792.000000    98.000000

# %%
df_vitals.describe()
# Out:
#                   ID             TIME             V1             V2  \
# count  199971.000000    199971.000000  134073.000000  134065.000000
# mean     4181.207135    667663.462742     123.726186      69.736404
# std       343.508698   1275026.711402      23.420448      15.418508
# min      3595.000000         0.000000       1.000000       2.000000
# 25%      3882.000000    127828.500000     107.000000      59.000000
# 50%      4191.000000    352106.000000     121.000000      68.000000
# 75%      4481.000000    775999.000000     139.000000      79.000000
# max      4792.000000  26366610.000000     301.000000     196.000000
#
#                   V3             V4             V5            V6  \
# count  144345.000000  136246.000000  136933.000000  49790.000000
# mean       86.423866      20.624782      97.488984     98.215260
# std        18.363086       5.934046       3.731745      1.193453
# min         1.000000       1.000000       2.000000     84.900000
# ...

# %%
df_labs.describe()
# Out:
#                   ID             TIME           L1           L2           L3  \
# count  199971.000000    199971.000000  4133.000000  4242.000000  4250.000000
# mean     4181.207135    667663.462742     7.366903    44.838413   118.978499
# std       343.508698   1275026.711402     0.178867    14.286385    96.607404
# min      3595.000000         0.000000     4.983503    12.665622     5.369376
# 25%      3882.000000    127828.500000     7.328580    36.622288    61.593676
# 50%      4191.000000    352106.000000     7.394292    41.860713    86.731180
# 75%      4481.000000    775999.000000     7.443579    49.160790   133.197751
# max      4792.000000  26366610.000000     7.654529   186.167395   745.546064
#
#                  L4            L5           L6            L7            L8  \
# count  11059.000000  12111.000000  4278.000000  10095.000000  10144.000000
# mean     137.681285      4.109035    26.235450     34.568019      1.939878
# ...
